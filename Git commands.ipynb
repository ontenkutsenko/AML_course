# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/My Drive/AML
# Out:
# /content/drive/My Drive/AML

# %%
! ls
# Out:
#  AML_course  'Future Readme.gdoc'  'Project artifacts'	'Working with Github repo.ipynb'

# %%
token = "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"

# %%
# !git config --global user.email 'ontenkutsenko@gmail.com'
# !git config --global user.name 'ontenkutsenko'

from getpass import getpass
password = getpass('Password:')
# !git config --global user.password password
# Out:
# Password:··········

# %%
# ! git clone https://{token}@github.com/{uname}/AML_course.git

# %%
# %cd AML_course/
# Out:
# /content/drive/My Drive/AML/AML_course

# %%
# !git pull
# Out:
# Updating d08acc0..5df865e
# Fast-forward
#  .gitignore                               |    5 +
#  Project/Classification model train.ipynb | 2653 +++++++++++++-
#  Project/Textual inversion test.ipynb     | 9476 +++++++++++++++++++++++++++++++++++++++++++++++++-
#  Project/modules/__init__.py              |    0
#  Project/modules/data_preprocessing.py    |   60 +
#  Project/modules/generate_images.py       |   25 +
#  Project/modules/textual_inversion.py     |    0
#  Project/modules/train_classfier.py       |  126 +
#  8 files changed, 12343 insertions(+), 2 deletions(-)
#  create mode 100644 Project/modules/__init__.py
#  create mode 100644 Project/modules/data_preprocessing.py
#  create mode 100644 Project/modules/generate_images.py
#  create mode 100644 Project/modules/textual_inversion.py
#  create mode 100644 Project/modules/train_classfier.py

# %%
# !git stash
# Out:
# Saved working directory and index state WIP on main: d08acc0 First experiments

# %%
! git add .

# %%
! git commit -m 'Textual inversion pipeline working, first training done'
# Out:
# [main c3a3bdb] Textual inversion pipeline working, first training done
#  2 files changed, 2 insertions(+), 9476 deletions(-)
#  rewrite Project/Textual inversion test.ipynb (99%)
#  rewrite Project/Whole pipeline.ipynb (72%)

# %%
! git push
# Out:
# Enumerating objects: 12, done.
# Counting objects: 100% (12/12), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (7/7), 1.70 MiB | 4.42 MiB/s, done.
# Total 7 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/ontenkutsenko/AML_course.git
#    c139245..6474b4d  main -> main
